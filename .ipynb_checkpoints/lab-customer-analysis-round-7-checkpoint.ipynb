# %% [markdown]
# <h1>Lab | Customer Analysis Round 7<h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme()
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import sklearn.metrics as metrics
from sklearn.preprocessing import PowerTransformer

data = pd.read_csv('./files_for_lab/csv_files/marketing_customer_analysis.csv')
data2 = data.copy()
data_tr = data.copy()

# %% [markdown]
# <h4>The function to clean and get X while dropping the column to predict and removing the rows with income 0, to get rid of the outliers.<h4>

# %%
def cleaner_processor_X(df):
    df = df.drop_duplicates()
    df = df.reset_index(drop = True)
    cols = []
    for col in df.columns:
        cols.append(col.lower().replace(' ', '_'))
    df.columns = cols
    df = df.select_dtypes(include = np.number)
    df = df.round(decimals = 2)
    df = df[df.income != 0]
    df = df.drop(['total_claim_amount'], axis=1)
    return df

# %% [markdown]
# Same function for y

# %%
def cleaner_processor_y(df):
    df = df.drop_duplicates()
    df = df.reset_index(drop = True)
    cols = []
    for col in df.columns:
        cols.append(col.lower().replace(' ', '_'))
    df.columns = cols
    df = df.select_dtypes(include = np.number)
    df = df.round(decimals = 2)
    df = df[df.income != 0]
    df = df['total_claim_amount']
    return df

# %%
X = cleaner_processor_X(data)
y = cleaner_processor_y(data)

# %%
#We will compare X to the dataframe without dropping the 0 income values. No need to standardize columnns
data2 = data2.drop(['Total Claim Amount'], axis=1)
correlation_matrix = data2.corr()

# %%
X
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                     2763.52   56274                    69
# 2                    12887.43   48767                   108
# 4                     2813.69   43836                    73
# 5                     8256.30   62902                    69
# 6                     5380.90   55350                    67
# ...                       ...     ...                   ...
# 9127                  5032.17   66367                    64
# 9128                  4100.40   47761                   104
# 9129                 23405.99   71941                    73
# 9130                  3096.51   21604                    79
# 9132                  7524.44   21941                    96
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 2                          18                             38
# 4                          12                             44
# 5                          14                             94
# 6                           0                             13
# ...                       ...                            ...
# 9127                        6                             48
# 9128                       16                             58
# 9129                       18                             89
# 9130                       14                             28
# 9132                       34                              3
#
#       number_of_open_complaints  number_of_policies
# 0                             0                   1
# 2                             0                   2
# 4                             0                   1
# 5                             0                   2
# 6                             0                   9
# ...                         ...                 ...
# 9127                          0                   3
# 9128                          0                   1
# 9129                          0                   2
# 9130                          0                   1
# 9132                          0                   3
#
# [6817 rows x 7 columns]

# %%
y
# Out:
# 0       384.81
# 2       566.47
# 4       138.13
# 5       159.38
# 6       321.60
#          ...
# 9127    307.20
# 9128    541.28
# 9129    198.23
# 9130    379.20
# 9132    691.20
# Name: total_claim_amount, Length: 6817, dtype: float64

# %%
correlations_matrix = X.corr()
correlations_matrix
# Out:
#                                customer_lifetime_value    income  \
# customer_lifetime_value                       1.000000  0.002915
# income                                        0.002915  1.000000
# monthly_premium_auto                          0.399491 -0.012372
# months_since_last_claim                       0.018531 -0.034453
# months_since_policy_inception                 0.011275  0.015799
# number_of_open_complaints                    -0.025038  0.016642
# number_of_policies                            0.022683 -0.001324
#
#                                monthly_premium_auto  months_since_last_claim  \
# customer_lifetime_value                    0.399491                 0.018531
# income                                    -0.012372                -0.034453
# monthly_premium_auto                       1.000000                 0.005887
# months_since_last_claim                    0.005887                 1.000000
# months_since_policy_inception              0.020112                -0.039993
# number_of_open_complaints                 -0.006476                 0.007744
# number_of_policies                        -0.026795                 0.017022
#
#                                months_since_policy_inception  \
# customer_lifetime_value                             0.011275
# income                                              0.015799
# monthly_premium_auto                                0.020112
# months_since_last_claim                            -0.039993
# months_since_policy_inception                       1.000000
# number_of_open_complaints                           0.005763
# number_of_policies                                 -0.020548
#
#                                number_of_open_complaints  number_of_policies
# customer_lifetime_value                        -0.025038            0.022683
# income                                          0.016642           -0.001324
# monthly_premium_auto                           -0.006476           -0.026795
# months_since_last_claim                         0.007744            0.017022
# months_since_policy_inception                   0.005763           -0.020548
# number_of_open_complaints                       1.000000            0.010004
# number_of_policies                              0.010004            1.000000

# %%
fig, axes = plt.subplots(1,2,figsize=(15,5), dpi=200)
sns.heatmap(correlation_matrix, annot=True, ax=axes[0])
axes[0].set_xlabel('Including 0 income')
sns.heatmap(correlations_matrix, annot=True, ax=axes[1])
axes[1].set_xlabel('Excluding 0 income')
plt.show()

# %% [markdown]
# We can onbserve that the correlation for the income has improved a bit but it is still low. Also, some values increase while others decrease. Not a big change in the model.

# %% [markdown]
# Since after dropping all the zero income rows the size has decreased, we will use a 30% test size (otherwise we would have less than 2000 values in the test set). Changed random seed to 75.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=75)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4771, 7)
# (2046, 7)
# (4771,)
# (2046,)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = lm.predict(X_train)
y_pred_test = lm.predict(X_test)

# %% [markdown]
# <h4>-R2<h4>

# %%
print(f'R2 train = {r2_score(y_train, y_pred_train):.4f}')
print(f'R2 test = {r2_score(y_test, y_pred_test):.4f}')

print('\nR2 before dropping zero income:')
print('R2 train = 0.5269')
print('R2 test = 0.4791 ')
# Out:
# R2 train = 0.4429
# R2 test = 0.4688
#
# -R2 before dropping zero income:
# R2 train = 0.5269
# R2 test = 0.4791

# %% [markdown]
# <h6><h6>

# %% [markdown]
# <h4>-RMSE<h4>

# %%
print(f'RMSE train = {(np.sqrt(mean_squared_error(y_train,y_pred_train))):.4f}')
print(f'RMSE test = {(np.sqrt(mean_squared_error(y_test,y_pred_test))):.4f}')

print('\nRMSE before dropping zero income:')
print('RMSE train = 202.3996')
print('RMSE test = 198.3635')
# Out:
# RMSE train = 189.8229
# RMSE test = 181.2082
#
# RMSE before dropping zero income:
# RMSE train = 202.3996
# RMSE test = 198.3635

# %% [markdown]
# <h6><h6>

# %% [markdown]
# <h4>-MAE<h4>

# %%
print (f'MAE train = {(metrics.mean_absolute_error(y_train, y_pred_train)):.4f}')
print (f'MAE test = {(metrics.mean_absolute_error(y_test, y_pred_test)):.4f}')

print('\nMAE before dropping zero income:')
print('MAE train = 145.0737')
print('MAE test = 143.5592')
# Out:
# MAE train = 134.6550
# MAE test = 131.0287
#
# MAE before dropping zero income:
# MAE train = 145.0737
# MAE test = 143.5592

# %% [markdown]
# <h6><h6>

# %% [markdown]
# <h4>-MSE<h4>

# %%
print (f'MSE train = {(metrics.mean_squared_error(y_train, y_pred_train)):.4f}')
print (f'MAE test = {(metrics.mean_squared_error(y_test, y_pred_test)):.4f}')

print('\nMSE before dropping zero income:')
print('MSE train = 40965.5800')
print('MAE test = 39348.0931')
# Out:
# MSE train = 36032.7391
# MAE test = 32836.4216
#
# MSE before dropping zero income:
# MSE train = 40965.5800
# MAE test = 39348.0931

# %% [markdown]
# <h4>We will now reshape the values with a normalization and then Power Transformer<h4>

# %% [markdown]
# We have to concat X and y so the transformations are applied to all values proportionally.

# %%
X_nrm = pd.concat([X,y], axis=1)

# %%
X_nrm
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                     2763.52   56274                    69
# 2                    12887.43   48767                   108
# 4                     2813.69   43836                    73
# 5                     8256.30   62902                    69
# 6                     5380.90   55350                    67
# ...                       ...     ...                   ...
# 9127                  5032.17   66367                    64
# 9128                  4100.40   47761                   104
# 9129                 23405.99   71941                    73
# 9130                  3096.51   21604                    79
# 9132                  7524.44   21941                    96
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 2                          18                             38
# 4                          12                             44
# 5                          14                             94
# 6                           0                             13
# ...                       ...                            ...
# 9127                        6                             48
# 9128                       16                             58
# 9129                       18                             89
# 9130                       14                             28
# 9132                       34                              3
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                             0                   1              384.81
# 2                             0                   2              566.47
# 4                             0                   1              138.13
# 5                             0                   2              159.38
# 6                             0                   9              321.60
# ...                         ...                 ...                 ...
# 9127                          0                   3              307.20
# 9128                          0                   1              541.28
# 9129                          0                   2              198.23
# 9130                          0                   1              379.20
# 9132                          0                   3              691.20
#
# [6817 rows x 8 columns]

# %%
transformer = MinMaxScaler().fit(X_nrm)
x_nrm = transformer.transform(X_nrm)
x_nrm = pd.DataFrame(x_nrm, columns=X_nrm.columns)
x_nrm
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 0                    0.007926  0.514064              0.033898
# 1                    0.132596  0.430601              0.199153
# 2                    0.008544  0.375778              0.050847
# 3                    0.075566  0.587755              0.033898
# 4                    0.040158  0.503791              0.025424
# ...                       ...       ...                   ...
# 6812                 0.035863  0.626279              0.012712
# 6813                 0.024389  0.419417              0.182203
# 6814                 0.262126  0.688250              0.050847
# 6815                 0.012027  0.128602              0.076271
# 6816                 0.066554  0.132349              0.148305
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                    0.914286                       0.050505
# 1                    0.514286                       0.383838
# 2                    0.342857                       0.444444
# 3                    0.400000                       0.949495
# 4                    0.000000                       0.131313
# ...                       ...                            ...
# 6812                 0.171429                       0.484848
# 6813                 0.457143                       0.585859
# 6814                 0.514286                       0.898990
# 6815                 0.400000                       0.282828
# 6816                 0.971429                       0.030303
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                           0.0               0.000            0.132973
# 1                           0.0               0.125            0.195763
# 2                           0.0               0.000            0.047709
# 3                           0.0               0.125            0.055054
# 4                           0.0               1.000            0.111125
# ...                         ...                 ...                 ...
# 6812                        0.0               0.250            0.106148
# 6813                        0.0               0.000            0.187056
# 6814                        0.0               0.125            0.068483
# 6815                        0.0               0.000            0.131034
# 6816                        0.0               0.250            0.238875
#
# [6817 rows x 8 columns]

# %%
transformer = PowerTransformer().fit(x_nrm) #default value is a Yeo-Johnson transform.
x_tr = transformer.transform(X_nrm)
x_tr = pd.DataFrame(x_tr, columns=X_nrm.columns)
x_tr
# Out:
#       customer_lifetime_value     income  monthly_premium_auto  \
# 0                    2.182981  24.629905              2.309956
# 1                    2.182981  24.524242              2.309956
# 2                    2.182981  24.443698              2.309956
# 3                    2.182981  24.710123              2.309956
# 4                    2.182981  24.617833              2.309956
# ...                       ...        ...                   ...
# 6812                 2.182981  24.748156              2.309956
# 6813                 2.182981  24.508620              2.309956
# 6814                 2.182981  24.804638              2.309956
# 6815                 2.182981  23.865905              2.309956
# 6816                 2.182981  23.879389              2.309956
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                   13.721787                      11.745047
# 1                   11.590815                      56.511004
# 2                   10.065010                      62.591719
# 3                   10.646343                     104.924370
# 4                   -1.693018                      25.800705
# ...                       ...                            ...
# 6812                 7.464477                      66.477623
# 6813                11.148860                      75.706715
# 6814                11.590815                     101.152875
# 6815                10.646343                      45.528372
# 6816                13.942886                       7.242675
#
#       number_of_open_complaints  number_of_policies  total_claim_amount
# 0                     -0.509523            1.718797             3.87301
# 1                     -0.509523            1.985446             3.87301
# 2                     -0.509523            1.718797             3.87301
# 3                     -0.509523            1.985446             3.87301
# 4                     -0.509523            2.089054             3.87301
# ...                         ...                 ...                 ...
# 6812                  -0.509523            2.048063             3.87301
# 6813                  -0.509523            1.718797             3.87301
# 6814                  -0.509523            1.985446             3.87301
# 6815                  -0.509523            1.718797             3.87301
# 6816                  -0.509523            2.048063             3.87301
#
# [6817 rows x 8 columns]

# %%
X = x_tr.drop(['total_claim_amount'], axis=1)
y = x_tr['total_claim_amount']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=75)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4771, 7)
# (2046, 7)
# (4771,)
# (2046,)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = lm.predict(X_train)
y_pred_test = lm.predict(X_test)

# %% [markdown]
# <h4>-R2<h4>

# %%
print(f'R2 train = {r2_score(y_train, y_pred_train):.4f}')
print(f'R2 test = {r2_score(y_test, y_pred_test):.4f}')
# Out:
# R2 train = 0.0012
# R2 test = -0.0338

# %% [markdown]
# <h6><h6>

# %% [markdown]
# <h4>-RMSE<h4>

# %%
print(f'RMSE train = {(np.sqrt(mean_squared_error(y_train,y_pred_train))):.4f}')
print(f'RMSE test = {(np.sqrt(mean_squared_error(y_test,y_pred_test))):.4f}')
# Out:
# RMSE train = 0.0704
# RMSE test = 0.0155

# %% [markdown]
# <h6><h6>

# %% [markdown]
# <h4>-MAE<h4>

# %%
print (f'MAE train = {(metrics.mean_absolute_error(y_train, y_pred_train)):.4f}')
print (f'MAE test = {(metrics.mean_absolute_error(y_test, y_pred_test)):.4f}')
# Out:
# MAE train = 0.0047
# MAE test = 0.0030

# %% [markdown]
# <h6><h6>

# %% [markdown]
# <h4>-MSE<h4>

# %%
print (f'MSE train = {(metrics.mean_squared_error(y_train, y_pred_train)):.4f}')
print (f'MAE test = {(metrics.mean_squared_error(y_test, y_pred_test)):.4f}')
# Out:
# MSE train = 0.0050
# MAE test = 0.0002

# %% [markdown]
# The values are now very small compared to the original ones. This is because the Power Transformer is like zooming inside a dataset, and since we had already removed the zero income values (which impacted heavily the income column) and we zoomed in even more into the data, we have a portion of it that looks way more normalized than originally.
